# %%
from sklearn.model_selection import train_test_split
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C
import numpy as np
import pandas as pd
import  gym
import seaborn as sns
import matplotlib.pyplot as plt
from gym_anytrading.envs import StocksEnv
from finta import TA
import os
import tensorboard
import tensorflow as tf
# Out:
# 2023-05-12 19:06:42.003465: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv("../../../data/all_stocks_5yr.csv")

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df['SMA'] = TA.SMA(df, 12)
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)
df[['MACD', 'MACD_signal']] = TA.MACD(df)
df.fillna(0, inplace=True)
df.set_index('Date',inplace=True)

# %%
x_train, x_test = train_test_split(df, test_size=0.1)
del df

# %%
models_dir = "models/A2C"
logdir = "logs"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)


def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Low', 'Volume', 'SMA', 'RSI', 'OBV', 'MACD', 'MACD_signal']].to_numpy()[start:end]
    return prices, signal_features


class MyCustomEnv(StocksEnv):
    _process_data = add_signals


env_train = MyCustomEnv(df=x_train, window_size=12, frame_bound=(12, x_train.shape[0]))
env_maker = lambda: env_train
env = DummyVecEnv([env_maker])

timesteps = 10_000

model = A2C('MlpPolicy', env=env_train, verbose=1, tensorboard_log=logdir)
for i in range(1, 30):
    model.learn(total_timesteps=timesteps, reset_num_timesteps=False, tb_log_name="A2C")
    model.save(f"{models_dir}/A2C{i * timesteps}")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs/A2C_0
# ------------------------------------
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | 0.00171  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 29       |
# |    value_loss         | 2.45e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.683   |
# |    explained_variance | 0.0302   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -5.75    |
# |    value_loss         | 177      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 287      |
# |    iterations         | 300      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.615   |
# |    explained_variance | -121     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0888   |
# |    value_loss         | 0.0646   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 306      |
# |    iterations         | 400      |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.621   |
# |    explained_variance | -0.0118  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 2.94     |
# |    value_loss         | 39.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 324      |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.67    |
# |    explained_variance | 0.109    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -24.8    |
# |    value_loss         | 1.15e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 600      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | -0.00269 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 43.4     |
# |    value_loss         | 1.17e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 700      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.639   |
# |    explained_variance | 0.0168   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -25.5    |
# |    value_loss         | 3.03e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 800      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.635   |
# |    explained_variance | -665     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.134    |
# |    value_loss         | 0.132    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 341      |
# |    iterations         | 900      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | -1.5     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -9.86    |
# |    value_loss         | 352      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 351      |
# |    iterations         | 1000     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.662   |
# |    explained_variance | -0.0121  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 39.1     |
# |    value_loss         | 3.29e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 1100     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0.00581  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -3.81    |
# |    value_loss         | 225      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 1200     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | -0.436   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -33.1    |
# |    value_loss         | 2.81e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 362       |
# |    iterations         | 1300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.645    |
# |    explained_variance | -1.27e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.0162    |
# |    value_loss         | 0.0392    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 1400     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | 0.00348  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 15.2     |
# |    value_loss         | 2.34e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 1500     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | -248     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0796  |
# |    value_loss         | 0.061    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 1600     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.686   |
# |    explained_variance | -0.0332  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 3.76     |
# |    value_loss         | 64.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 1700     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.649   |
# |    explained_variance | -0.0183  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -14.9    |
# |    value_loss         | 302      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 1800     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | -0.00735 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 17.6     |
# |    value_loss         | 1.53e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 1900     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.593   |
# |    explained_variance | -6.1e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -333     |
# |    value_loss         | 4.81e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 2000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.546   |
# |    explained_variance | 0.00059  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 13.6     |
# |    value_loss         | 362      |
# ------------------------------------
# Logging to logs/A2C_0
# ------------------------------------
# | time/                 |          |
# |    fps                | 404      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -0.482   |
# |    explained_variance | -0.00277 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -24.5    |
# |    value_loss         | 2.09e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 400      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.572   |
# |    explained_variance | 0.00117  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -71.1    |
# |    value_loss         | 1.69e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 412      |
# |    iterations         | 300      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.485   |
# |    explained_variance | -130     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0103  |
# |    value_loss         | 0.0201   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 419      |
# |    iterations         | 400      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | -0.0144  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -1.05    |
# |    value_loss         | 97.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 423      |
# |    iterations         | 500      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.617   |
# |    explained_variance | -0.00124 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -55      |
# |    value_loss         | 1.37e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 424      |
# |    iterations         | 600      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.541   |
# |    explained_variance | 0.0115   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 8.89     |
# |    value_loss         | 136      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 422      |
# |    iterations         | 700      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.00121 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -70.7    |
# |    value_loss         | 2.4e+04  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 411      |
# |    iterations         | 800      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.417   |
# |    explained_variance | 0.143    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -44.5    |
# |    value_loss         | 3.04e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 900      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.506   |
# |    explained_variance | 0.00272  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -20.5    |
# |    value_loss         | 3.03e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 392      |
# |    iterations         | 1000     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.426   |
# |    explained_variance | 0.0033   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 4.09     |
# |    value_loss         | 1.66e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 386       |
# |    iterations         | 1100      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -0.301    |
# |    explained_variance | -5.82e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 706       |
# |    value_loss         | 1.28e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 380       |
# |    iterations         | 1200      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -0.25     |
# |    explained_variance | -0.000787 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -3.69     |
# |    value_loss         | 1.05e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 378       |
# |    iterations         | 1300      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.138    |
# |    explained_variance | -7.96e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 0.00229   |
# |    value_loss         | 0.0105    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 1400     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.0872  |
# |    explained_variance | -132     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.000169 |
# |    value_loss         | 0.00184  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 368       |
# |    iterations         | 1500      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -0.113    |
# |    explained_variance | -2.02e+04 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | 0.000981  |
# |    value_loss         | 0.0042    |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 1600     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.0332  |
# |    explained_variance | -661     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 9.9e-05  |
# |    value_loss         | 0.00135  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 1700     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.219   |
# |    explained_variance | -38.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.000764 |
# |    value_loss         | 0.00156  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 369       |
# |    iterations         | 1800      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -0.272    |
# |    explained_variance | -497      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -0.000585 |
# |    value_loss         | 0.00151   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 1900     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.403   |
# |    explained_variance | -0.00877 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -42.9    |
# |    value_loss         | 2.85e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 2000     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.336   |
# |    explained_variance | -223     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00553  |
# |    value_loss         | 0.00499  |
# ------------------------------------
# Logging to logs/A2C_0
# ------------------------------------
# | time/                 |          |
# |    fps                | 398      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.589   |
# |    explained_variance | -26.8    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.00358  |
# |    value_loss         | 0.000667 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 387      |
# |    iterations         | 200      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.589   |
# |    explained_variance | 0.0163   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 33.2     |
# |    value_loss         | 5.68e+03 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 366       |
# |    iterations         | 300       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.615    |
# |    explained_variance | -0.000401 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | 4.31      |
# |    value_loss         | 909       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.427   |
# |    explained_variance | -0.00141 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 16.9     |
# |    value_loss         | 330      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 373       |
# |    iterations         | 500       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.155    |
# |    explained_variance | -0.000182 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.144    |
# |    value_loss         | 623       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 600      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.196   |
# |    explained_variance | -110     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.008   |
# |    value_loss         | 0.0136   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 700      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.189   |
# |    explained_variance | -668     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.00226 |
# |    value_loss         | 0.00165  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 800      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.481   |
# |    explained_variance | -0.00107 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -8.99    |
# |    value_loss         | 622      |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 31
#      29 model = A2C('MlpPolicy', env=env_train, verbose=1, tensorboard_log=logdir)
#      30 for i in range(1, 30):
# ---> 31     model.learn(total_timesteps=timesteps, reset_num_timesteps=False, tb_log_name="A2C")
#      32     model.save(f"{models_dir}/A2C{i * timesteps}")
#
# File ~/anaconda3/envs/dask_env/lib/python3.10/site-packages/stable_baselines3/a2c/a2c.py:194, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     185 def learn(
#     186     self: SelfA2C,
#     187     total_timesteps: int,
#    (...)
#     192     progress_bar: bool = False,
#     193 ) -> SelfA2C:
# --> 194     return super().learn(
#     195         total_timesteps=total_timesteps,
#     196         callback=callback,
#     197         log_interval=log_interval,
#     198         tb_log_name=tb_log_name,
#     199         reset_num_timesteps=reset_num_timesteps,
#     200         progress_bar=progress_bar,
#     201     )
#
# File ~/anaconda3/envs/dask_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:250, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     247 callback.on_training_start(locals(), globals())
#     249 while self.num_timesteps < total_timesteps:
# --> 250     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     252     if continue_training is False:
#     253         break
#
# File ~/anaconda3/envs/dask_env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:207, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     204             terminal_value = self.policy.predict_values(terminal_obs)[0]
#     205         rewards[idx] += self.gamma * terminal_value
# --> 207 rollout_buffer.add(self._last_obs, actions, rewards, self._last_episode_starts, values, log_probs)
#     208 self._last_obs = new_obs
#     209 self._last_episode_starts = dones
#
# File ~/anaconda3/envs/dask_env/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:424, in RolloutBuffer.add(self, obs, action, reward, episode_start, value, log_prob)
#     405 def add(
#     406     self,
#     407     obs: np.ndarray,
#    (...)
#     412     log_prob: th.Tensor,
#     413 ) -> None:
#     414     """
#     415     :param obs: Observation
#     416     :param action: Action
#    (...)
#     422         following the current policy.
#     423     """
# --> 424     if len(log_prob.shape) == 0:
#     425         # Reshape 0-d tensor to avoid error
#     426         log_prob = log_prob.reshape(-1, 1)
#     428     # Reshape needed when using multiple envs with discrete observations
#     429     # as numpy cannot broadcast (n_discrete,) to (n_discrete, 1)
#
# KeyboardInterrupt:

# %% [markdown]
# | Metric                    | Description                                                                       |
# |---------------------------|-----------------------------------------------------------------------------------|
# | time/fps                  | Number of steps per second taken by the model during training.                    |
# | iterations                | Number of iterations completed during training.                                   |
# | time_elapsed              | Total time elapsed during training in seconds.                                    |
# | total_timesteps           | Total number of timesteps taken by the model during training.                     |
# | train/entropy_loss        | Entropy loss of the policy during training. The goal is to have enough entropy... |
# | train/explained_variance  | Explained variance of the value function during training. The goal is to have ... |
# | train/learning_rate       | Learning rate of the optimizer during training. It is adjusted according to th... |
# | train/n_updates           | Number of updates made to the model during training.                               |
# | train/policy_loss         | Policy loss of the A2C algorithm during training. The goal is to minimize it t... |
# | train/value_loss          | Value function loss of the A2C algorithm during training. The goal is to minimi... |

# %%
env = MyCustomEnv(df=x_test, window_size=12, frame_bound=(12, 100))
obs = env.reset()
while True:
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done:
        print("info", info)
        break
plt.figure(figsize=(15, 8))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': -1201.8482000000004, 'total_profit': 0.0008932483983427224, 'position': 1}

# %%
from keras.callbacks import TensorBoard
# %load_ext tensorboard
log_dir = 'logs/'  # the directory where you saved your TensorBoard logs
tensorboard_callback = TensorBoard(log_dir=log_dir)

# %tensorboard --logdir logs/  # visualize the logs in TensorBoard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Launching TensorBoard...
#       <iframe id="tensorboard-frame-bd335f77d7f5ecd0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bd335f77d7f5ecd0");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# | Metric                     | Definition                               | Goal                                                       |
# |----------------------------|------------------------------------------|------------------------------------------------------------|
# | `time/fps`                 | Steps per second                         | Maximize                                                   |
# | `train/entropy_loss`       | Entropy loss of policy                    | High enough for exploration, but not too high to prevent convergence |
# | `train/explained_variance` | Explained variance of value function   | High enough to accurately estimate state values              |
# | `train/learning_rate`      | Learning rate of optimizer                | Adjust according to learning schedule and convergence       |
# | `train/policy_loss`        | Policy loss of A2C                        | Minimize to improve policy performance                       |
# | `train/value_loss`         | Value function loss of A2C                | Minimize to improve value function accuracy                  |
